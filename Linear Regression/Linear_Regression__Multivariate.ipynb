# %% [markdown]
# <a href="https://colab.research.google.com/github/Neethuharii/Foundatin-of-ML/blob/main/Linear%20Regression/Linear_Regression__Multivariate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
data=pd.read_csv('/content/homeprices-2.csv')
data
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
data.bedrooms.median()
# Out:
# 4.0

# %%
data.bedrooms=data.bedrooms.fillna(data.bedrooms.median())

# %%
data
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
data1=data.drop('price',axis='columns')
data1
# Out:
#    area  bedrooms  age
# 0  2600       3.0   20
# 1  3000       4.0   15
# 2  3200       4.0   18
# 3  3600       3.0   30
# 4  4000       5.0    8
# 5  4100       6.0    8

# %%
reg=linear_model.LinearRegression()
reg
# Out:
# LinearRegression()

# %%
price=data.price
price
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    595000
# 4    760000
# 5    810000
# Name: price, dtype: int64

# %%
reg.fit(data1,price)
# Out:
# LinearRegression()

# %% [markdown]
# Find price of home with 3000 sqr ft area, 3 bedrooms, 40 year old

# %%
reg.predict([[3000,3,40]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([498408.25158031])

# %% [markdown]
# Find price of home with 2500 sqr ft area, 4 bedrooms, 5 year old

# %%
reg.predict([[2500,4,5]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([578876.03748933])

# %% [markdown]
# ##Excercise

# %%
hire_data=pd.read_csv('/content/hiring.csv')
hire_data
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
hire_data.experience=hire_data.experience.fillna('Zero')

# %%
hire_data.experience
# Out:
# 0      Zero
# 1      Zero
# 2      five
# 3       two
# 4     seven
# 5     three
# 6       ten
# 7    eleven
# Name: experience, dtype: object

# %%
# !pip install word2number
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5568 sha256=09fe4f177aec3d924376675b00536225c58d05be996e27e51eb0c9c35880b9e4
#   Stored in directory: /root/.cache/pip/wheels/84/ff/26/d3cfbd971e96c5aa3737ecfced81628830d7359b55fbb8ca3b
# Successfully built word2number
# ...

# %%
from word2number import w2n

# %%
hire_data.experience = hire_data.experience.apply(w2n.word_to_num)
hire_data.experience
# Out:
# 0     0
# 1     0
# 2     5
# 3     2
# 4     7
# 5     3
# 6    10
# 7    11
# Name: experience, dtype: int64

# %%
import math
median_test_score = math.floor(hire_data['test_score(out of 10)'].mean())
median_test_score
# Out:
# 7

# %%
hire_data['test_score(out of 10)'] = hire_data['test_score(out of 10)'].fillna(median_test_score)

# %%
hire_data['test_score(out of 10)']
# Out:
# 0     8.0
# 1     8.0
# 2     6.0
# 3    10.0
# 4     9.0
# 5     7.0
# 6     7.0
# 7     7.0
# Name: test_score(out of 10), dtype: float64

# %%
hire_data
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    7.0                           7      72000
# 7          11                    7.0                           8      80000

# %%
reg1=linear_model.LinearRegression()
reg1
# Out:
# LinearRegression()

# %%
hire_data1=hire_data.drop('salary($)',axis='columns')
hire_data1
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)
# 0           0                    8.0                           9
# 1           0                    8.0                           6
# 2           5                    6.0                           7
# 3           2                   10.0                          10
# 4           7                    9.0                           6
# 5           3                    7.0                          10
# 6          10                    7.0                           7
# 7          11                    7.0                           8

# %%
salary = hire_data['salary($)']
salary
# Out:
# 0    50000
# 1    45000
# 2    60000
# 3    65000
# 4    70000
# 5    62000
# 6    72000
# 7    80000
# Name: salary($), dtype: int64

# %%
reg1.fit(hire_data1,salary)
# Out:
# LinearRegression()

# %% [markdown]
# 2 yr experience, 9 test score, 6 interview score

# %%
reg1.predict([[2,9,6]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([53713.86677124])

# %% [markdown]
# 12 yr experience, 10 test score, 10 interview score

# %%
reg1.predict([[12,10,10]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([93747.79628651])
