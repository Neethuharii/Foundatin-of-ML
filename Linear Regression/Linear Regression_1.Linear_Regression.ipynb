# %% [markdown]
# <a href="https://colab.research.google.com/github/Neethuharii/Foundatin-of-ML/blob/main/Linear%20Regression/Linear%20Regression_1.Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/homeprices.csv')

# %%
data
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(data.area,data.price,color='red',marker='*')

# %%
data1=data.drop('price',axis='columns')

# %%
data1
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
price=data.price
price
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %% [markdown]
# create linear regression model

# %%
reg=linear_model.LinearRegression()
reg.fit(data1,price)
# Out:
# LinearRegression()

# %% [markdown]
# (1) Predict price of a home with area = 3300 sqr ft

# %%
reg.predict([[3300]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_   #m
# Out:
# array([135.78767123])

# %%
reg.intercept_ #b
# Out:
# 180616.43835616432

# %% [markdown]
# Y = m * X + b (m is coefficient and b is intercept)

# %%
3300*135.78767123+180616.43835616432
# Out:
# 628715.7534151643

# %% [markdown]
# (1) Predict price of a home with area = 5000 sqr ft

# %%
reg.predict([[5000]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %% [markdown]
# Generate CSV file with list of home price predictions

# %%
area_data=pd.read_csv('/content/areas.csv')
area_data
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
p=reg.predict(area_data)
p
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
area_data.to_csv("prediction.csv")

# %% [markdown]
# ##Excersise

# %%
can_data=pd.read_csv('/content/canada_per_capita_income.csv')
can_data
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
plt.xlabel('year')
plt.ylabel('per capita income (US$)')
plt.scatter(can_data.year,can_data['per capita income (US$)'],color='red',marker='*')

# %%
regre=linear_model.LinearRegression()
regre
# Out:
# LinearRegression()

# %% [markdown]
# canada's per capita income in year 2020

# %%
per = can_data["per capita income (US$)"]
per
# Out:
# 0      3399.299037
# 1      3768.297935
# 2      4251.175484
# 3      4804.463248
# 4      5576.514583
# 5      5998.144346
# 6      7062.131392
# 7      7100.126170
# 8      7247.967035
# 9      7602.912681
# 10     8355.968120
# 11     9434.390652
# 12     9619.438377
# 13    10416.536590
# 14    10790.328720
# 15    11018.955850
# 16    11482.891530
# 17    12974.806620
# 18    15080.283450
# 19    16426.725480
# 20    16838.673200
# 21    17266.097690
# 22    16412.083090
# 23    15875.586730
# 24    15755.820270
# 25    16369.317250
# 26    16699.826680
# 27    17310.757750
# 28    16622.671870
# 29    17581.024140
# 30    18987.382410
# 31    18601.397240
# 32    19232.175560
# 33    22739.426280
# 34    25719.147150
# 35    29198.055690
# 36    32738.262900
# 37    36144.481220
# 38    37446.486090
# 39    32755.176820
# 40    38420.522890
# 41    42334.711210
# 42    42665.255970
# 43    42676.468370
# 44    41039.893600
# 45    35175.188980
# 46    34229.193630
# ...

# %%
year = year.values.reshape(-1, 1)

# %%
regre.fit(year,per)
# Out:
# LinearRegression()

# %%
regre.predict([[2020]])
# Out:
# array([41288.69409442])
